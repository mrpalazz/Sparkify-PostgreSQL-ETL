# %%
import pandas as pd
import json

# %%
 df = pd.read_json('data/log_data/2018/11/2018-11-01-events.json', lines=True)

# %%
df.head(10)
# Out:
#                        artist       auth firstName gender  itemInSession  \
# 0                        None  Logged In    Walter      M              0
# 1                        None  Logged In    Kaylee      F              0
# 2                     Des'ree  Logged In    Kaylee      F              1
# 3                        None  Logged In    Kaylee      F              2
# 4                     Mr Oizo  Logged In    Kaylee      F              3
# 5                  Tamba Trio  Logged In    Kaylee      F              4
# 6              The Mars Volta  Logged In    Kaylee      F              5
# 7           Infected Mushroom  Logged In    Kaylee      F              6
# 8  Blue October / Imogen Heap  Logged In    Kaylee      F              7
# 9                   Girl Talk  Logged In    Kaylee      F              8
#
#   lastName     length level                           location method  \
# 0     Frye        NaN  free  San Francisco-Oakland-Hayward, CA    GET
# 1  Summers        NaN  free        Phoenix-Mesa-Scottsdale, AZ    GET
# 2  Summers  246.30812  free        Phoenix-Mesa-Scottsdale, AZ    PUT
# 3  Summers        NaN  free        Phoenix-Mesa-Scottsdale, AZ    GET
# 4  Summers  144.03873  free        Phoenix-Mesa-Scottsdale, AZ    PUT
# 5  Summers  177.18812  free        Phoenix-Mesa-Scottsdale, AZ    PUT
# 6  Summers  380.42077  free        Phoenix-Mesa-Scottsdale, AZ    PUT
# 7  Summers  440.26730  free        Phoenix-Mesa-Scottsdale, AZ    PUT
# 8  Summers  241.39710  free        Phoenix-Mesa-Scottsdale, AZ    PUT
# 9  Summers  160.15628  free        Phoenix-Mesa-Scottsdale, AZ    PUT
#
#        page   registration  sessionId                          song  status  \
# 0      Home  1540919166796         38                          None     200
# 1      Home  1540344794796        139                          None     200
# 2  NextSong  1540344794796        139                  You Gotta Be     200
# 3   Upgrade  1540344794796        139                          None     200
# 4  NextSong  1540344794796        139                       Flat 55     200
# 5  NextSong  1540344794796        139  Quem Quiser Encontrar O Amor     200
# 6  NextSong  1540344794796        139                     Eriatarka     200
# 7  NextSong  1540344794796        139               Becoming Insane     200
# 8  NextSong  1540344794796        139               Congratulations     200
# 9  NextSong  1540344794796        139                    Once again     200
#
#               ts                                          userAgent  userId
# 0  1541105830796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      39
# 1  1541106106796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 2  1541106106796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 3  1541106132796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 4  1541106352796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 5  1541106496796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 6  1541106673796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 7  1541107053796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 8  1541107493796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 9  1541107734796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8

# %%
 df2 = pd.read_json('data/song_data/A/A/A/TRAAAAW128F429D538.json', lines=True)

# %%
df2.head(10)
# Out:
#             artist_id  artist_latitude  artist_location  artist_longitude  \
# 0  ARD7TVE1187B99BFB1              NaN  California - LA               NaN
#
#   artist_name   duration  num_songs             song_id             title  \
# 0      Casual  218.93179          1  SOMZWCG12A8C13C480  I Didn't Mean To
#
#    year
# 0     0
